# %% [markdown]
# <a href="https://colab.research.google.com/github/Miguelrodriguez55/TALLER./blob/main/taller_importacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Taller IA

# %%
#1. 1Buscar la base de países del World Economic Outlook (WEO) del FMI, subirla a su Drive y cargarla en el notebook conectándose a Google Drive

# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive, files
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BaseTaller'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#2.  Conectarse a la API del Banco Mundial y traer datos de inflación para Colombia, Ecuador, Brasil, Chile, México y Perú, años 2010-2023.

# %%
# !pip install wbdata
# Out:
# Collecting wbdata
#   Downloading wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting backoff<3,>=2.2.1 (from wbdata)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Downloading dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Collecting decorator<6,>=5.1.1 (from wbdata)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from wbdata) (2.32.4)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Downloading shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: tabulate<1,>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Downloading wbdata-1.1.0-py3-none-any.whl (18 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading dateparser-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 19.5 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Installing collected packages: appdirs, decorator, cachetools, backoff, shelved-cache, dateparser, wbdata
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.6
#     Uninstalling cachetools-6.2.6:
#       Successfully uninstalled cachetools-6.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# Successfully installed appdirs-1.4.4 backoff-2.2.1 cachetools-5.5.2 dateparser-1.3.0 decorator-5.2.1 shelved-cache-0.3.1 wbdata-1.1.0

# %%
import wbdata
import datetime

# %%
indicador = {"FP.CPI.TOTL.ZG": "Inflación"}

fecha_inicio = datetime.datetime(2010,1,1)
fecha_fin = datetime.datetime(2023,1,1)

paises = ["COL","ECU","BRA","CHL","MEX","PER"]

inflacion = wbdata.get_dataframe(indicador, country=paises, date=(fecha_inicio, fecha_fin))
inflacion = inflacion.reset_index()


print(inflacion.head())
print(inflacion.tail(10))
print(inflacion.sample(3))
print(inflacion.iloc[1:5,[1]])
print(len(inflacion))
print(inflacion.shape)
print(inflacion.columns)
print(inflacion.dtypes)
print(inflacion.info())
# Out:
#   country  date  Inflación
# 0  Brazil  2023   4.593563
# 1  Brazil  2022   9.280106
# 2  Brazil  2021   8.301660
# 3  Brazil  2020   3.211768
# 4  Brazil  2019   3.732976
#    country  date  Inflación
# 74    Peru  2019   2.252122
# 75    Peru  2018   1.509154
# 76    Peru  2017   2.994900
# 77    Peru  2016   3.557177
# 78    Peru  2015   3.398092
# 79    Peru  2014   3.411946
# 80    Peru  2013   2.767897
# 81    Peru  2012   3.611213
# 82    Peru  2011   3.369311
# 83    Peru  2010   1.528321
#     country  date  Inflación
# 80     Peru  2013   2.767897
# 43  Ecuador  2022   3.466170
# 74     Peru  2019   2.252122
#    date
# 1  2022
# 2  2021
# 3  2020
# 4  2019
# 84
# (84, 3)
# Index(['country', 'date', 'Inflación'], dtype='object')
# country       object
# date          object
# Inflación    float64
# dtype: object
# <class 'wbdata.client.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    84 non-null     object
#  1   date       84 non-null     object
#  2   Inflación  84 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.1+ KB
# None

# %%
#3. Conectarse a la API del Banco Mundial y traer los siguientes datos para Alemania 2010-2023: crecimiento del PIB, PIB per cápita en PPA, tasa de inflación, tasa de desempleo y población.

# %%
indicadores = {
"NY.GDP.MKTP.KD.ZG":"Crecimiento PIB",
"NY.GDP.PCAP.PP.CD":"PIB per cápita PPA",
"FP.CPI.TOTL.ZG":"Inflación",
"SL.UEM.TOTL.ZS":"Desempleo",
"SP.POP.TOTL":"Población"
}

fecha_inicio = datetime.datetime(2010,1,1)
fecha_fin = datetime.datetime(2023,1,1)

pais = ["DEU"]

alemania = wbdata.get_dataframe(indicadores, country=pais, date=(fecha_inicio, fecha_fin))

print(alemania.head())
print(alemania.tail(10))
print(alemania.sample(3))
print(alemania.iloc[1:5,[1]])
print(len(alemania))
print(alemania.shape)
print(alemania.columns)
print(alemania.dtypes)
print(alemania.info())
# Out:
#       Crecimiento PIB  PIB per cápita PPA  Inflación  Desempleo   Población
# date
# 2023        -0.869648        71684.031188   5.946437      3.071  83287273.0
# 2022         1.809258        69048.988404   6.872574      3.137  83177813.0
# 2021         3.910000        62530.765320   3.066667      3.594  83196078.0
# 2020        -4.131914        58685.872700   0.144878      3.881  83160871.0
# 2019         0.977735        59270.727650   1.445660      3.163  83092962.0
#       Crecimiento PIB  PIB per cápita PPA  Inflación  Desempleo   Población
# date
# 2019         0.977735        59270.727650   1.445660      3.163  83092962.0
# 2018         1.135696        56273.040563   1.732169      3.384  82905782.0
# 2017         2.797907        54110.253665   1.509495      3.781  82657002.0
# 2016         2.222222        51569.901684   0.491747      4.104  82348669.0
# 2015         1.663006        48545.400722   0.514426      4.612  81686611.0
# 2014         2.180186        47938.796821   0.906794      4.979  80982500.0
# 2013         0.396996        45889.017302   1.504723      5.316  80645605.0
# 2012         0.463512        44229.394192   2.008489      5.372  80425823.0
# 2011         3.757969        43398.344399   2.075173      5.967  80274983.0
# 2010         4.134638        39726.098692   1.103810      7.043  81776930.0
#       Crecimiento PIB  PIB per cápita PPA  Inflación  Desempleo   Población
# date
# 2021         3.910000        62530.765320   3.066667      3.594  83196078.0
# 2023        -0.869648        71684.031188   5.946437      3.071  83287273.0
# 2010         4.134638        39726.098692   1.103810      7.043  81776930.0
#       PIB per cápita PPA
# date
# 2022        69048.988404
# 2021        62530.765320
# 2020        58685.872700
# 2019        59270.727650
# 14
# (14, 5)
# Index(['Crecimiento PIB', 'PIB per cápita PPA', 'Inflación', 'Desempleo',
#        'Población'],
#       dtype='object')
# Crecimiento PIB       float64
# PIB per cápita PPA    float64
# Inflación             float64
# Desempleo             float64
# Población             float64
# dtype: object
# <class 'wbdata.client.DataFrame'>
# Index: 14 entries, 2023 to 2010
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Crecimiento PIB     14 non-null     float64
#  1   PIB per cápita PPA  14 non-null     float64
#  2   Inflación           14 non-null     float64
#  3   Desempleo           14 non-null     float64
#  4   Población           14 non-null     float64
# dtypes: float64(5)
# memory usage: 672.0+ bytes
# None

# %%
#4. Traer dos conjuntos de datos de la página de datos abiertos del Gobierno de Colombia utilizando API. Los que le llamen la atención.

# %%
import requests

# %%
#ESTERILIZACIONES CANINAS Y FELINAS EN MADRID CUNDI.
url = "https://www.datos.gov.co/resource/ezzu-ke2k.json"
response = requests.get(url)
data = response.json()

perros = pd.DataFrame(data)

print(perros.head())
print(perros.tail(10))
print(perros.sample(3))
print(perros.iloc[1:5,[1]])
print(len(perros))
print(perros.shape)
print(perros.columns)
print(perros.dtypes)
print(perros.info())
# Out:
#   item        no   a_o mes barrio_o_vereda poblacion_beneficiada  \
# 0    1  001.25ES  2025   1         SOSIEGO             CALLEJERO
# 1    2  002.25ES  2025   1           CANEY             CALLEJERO
# 2    3  003.25ES  2025   1         SOSIEGO             CALLEJERO
# 3    4  004.25ES  2025   1          ALCALA             CALLEJERO
# 4    5  005.25ES  2025   1     PROSPERIDAD      GRUPO ANIMALISTA
#
#   canino_hembra canino_macho felino_hembra felino_macho
# 0             1            0             0            0
# 1             0            1             0            0
# 2             0            0             1            0
# 3             0            0             0            1
# 4             1            0             0            0
#     item          no   a_o mes  barrio_o_vereda poblacion_beneficiada  \
# 462  463    462.25ES  2025  11       SANTA CRUZ                SISBEN
# 463  464    463.25ES  2025  11  ALTOS DE MADRID                SISBEN
# 464  465    464.25ES  2025  11       ALCAPARROS                SISBEN
# 465  466          NA  2025  11       BIBLIOTECA                IPYBAC
# 466  467    465.25ES  2025  11       MARRANERAS                VEREDA
# 467  468    466.25ES  2025  11        LA HUERTA             CALLEJERO
# 468  469    467.25ES  2025  11        ARRAYANES                SISBEN
# 469  470    468.25ES  2025  11    LOS ARRAYANES                SISBEN
# 470  471    468.25ES  2025  12    SANTA MATILDE                SISBEN
# 471  472  1913982025  2025  12         SAN JOSE                IPYBAC
#
#     canino_hembra canino_macho felino_hembra felino_macho
# 462             0            0             0            1
# 463             0            0             0            1
# 464             0            0             0            1
# 465            28           12            40            0
# 466             0            1             0            0
# 467             0            1             0            0
# 468             0            0             0            1
# 469             0            0             0            1
# 470             0            0             0            1
# 471           130            0             0            0
#     item        no   a_o mes         barrio_o_vereda poblacion_beneficiada  \
# 51    52  052.25ES  2025   4  PARQUES DE SANTA MARIA                SISBÉN
# 445  446  445.25ES  2025  11            SAN BERNARDO                SISBEN
# 294  295  295.25ES  2025   7               V. CHAUTA                SISBÉN
#
#     canino_hembra canino_macho felino_hembra felino_macho
# 51              0            0             1            0
# 445             0            0             0            1
# 294             0            0             1            0
#          no
# 1  002.25ES
# 2  003.25ES
# 3  004.25ES
# 4  005.25ES
# 472
# (472, 10)
# Index(['item', 'no', 'a_o', 'mes', 'barrio_o_vereda', 'poblacion_beneficiada',
#        'canino_hembra', 'canino_macho', 'felino_hembra', 'felino_macho'],
#       dtype='object')
# item                     object
# no                       object
# a_o                      object
# mes                      object
# barrio_o_vereda          object
# poblacion_beneficiada    object
# canino_hembra            object
# canino_macho             object
# felino_hembra            object
# felino_macho             object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item                   472 non-null    object
#  1   no                     472 non-null    object
#  2   a_o                    472 non-null    object
#  3   mes                    472 non-null    object
#  4   barrio_o_vereda        472 non-null    object
#  5   poblacion_beneficiada  472 non-null    object
#  6   canino_hembra          472 non-null    object
#  7   canino_macho           472 non-null    object
#  8   felino_hembra          472 non-null    object
#  9   felino_macho           472 non-null    object
# dtypes: object(10)
# memory usage: 37.0+ KB
# None

# %%
#Abuso Sexual
url1 = "https://www.datos.gov.co/resource/jnb2-jpjv.json"
response1 = requests.get(url1)
data1 = response1.json()

abuso = pd.DataFrame(data1)

print(abuso.head())
print(abuso.tail(10))
print(abuso.sample(3))
print(abuso.iloc[1:5,[1]])
print(len(abuso))
print(abuso.shape)
print(abuso.columns)
print(abuso.dtypes)
print(abuso.info())
# Out:
#         sexo edad_a_o     grupo_edad     dx_nombre codigo_dx
# 0   Femenino        1  B. 1 y 5 Años  ABUSO SEXUAL      T742
# 1  Masculino        1  B. 1 y 5 Años  ABUSO SEXUAL      T742
# 2  Masculino        2  B. 1 y 5 Años  ABUSO SEXUAL      T742
# 3   Femenino        3  B. 1 y 5 Años  ABUSO SEXUAL      T742
# 4   Femenino        3  B. 1 y 5 Años  ABUSO SEXUAL      T742
#         sexo edad_a_o       grupo_edad     dx_nombre codigo_dx
# 77  Femenino       17  E. 15 y 20 Años  ABUSO SEXUAL      T742
# 78  Femenino       17  E. 15 y 20 Años  ABUSO SEXUAL      T742
# 79  Femenino       18  E. 15 y 20 Años  ABUSO SEXUAL      T742
# 80  Femenino       20  E. 15 y 20 Años  ABUSO SEXUAL      T742
# 81  Femenino       22  F. 21 y 25 Años  ABUSO SEXUAL      T742
# 82  Femenino       22  F. 21 y 25 Años  ABUSO SEXUAL      T742
# 83  Femenino       23  F. 21 y 25 Años  ABUSO SEXUAL      T742
# 84  Femenino       26  G. 26 y 30 Años  ABUSO SEXUAL      T742
# 85  Femenino       29  G. 26 y 30 Años  ABUSO SEXUAL      T742
# 86  Femenino       32  H. 31 y 35 Años  ABUSO SEXUAL      T742
#         sexo edad_a_o       grupo_edad     dx_nombre codigo_dx
# 11  Femenino        5    B. 1 y 5 Años  ABUSO SEXUAL      T742
# 35  Femenino       11  D. 11 y 15 Años  ABUSO SEXUAL      T742
# 80  Femenino       20  E. 15 y 20 Años  ABUSO SEXUAL      T742
#   edad_a_o
# 1        1
# 2        2
# 3        3
# 4        3
# 87
# (87, 5)
# Index(['sexo', 'edad_a_o', 'grupo_edad', 'dx_nombre', 'codigo_dx'], dtype='object')
# sexo          object
# edad_a_o      object
# grupo_edad    object
# dx_nombre     object
# codigo_dx     object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sexo        87 non-null     object
#  1   edad_a_o    87 non-null     object
#  2   grupo_edad  87 non-null     object
#  3   dx_nombre   87 non-null     object
#  4   codigo_dx   87 non-null     object
# dtypes: object(5)
# memory usage: 3.5+ KB
# None

# %%
#5.  Investigue otra página de donde pueda traer datos mediante API y cargue el conjunto de datos en el notebook.

# %%
# Western North American FLEXPART Back Trajectory 2021 Data
url2 = "https://asdc.larc.nasa.gov/wagdocuments/602/Receptor_western_NAmerica_ozone_obs_1994_2021_from900to300.csv"

nasa = pd.read_csv(url2)

print(nasa.head())
print(nasa.tail(10))
print(nasa.sample(3))
print(nasa.iloc[1:5,[1]])
print(len(nasa))
print(nasa.shape)
print(nasa.columns)
print(nasa.dtypes)
print(nasa.info())
# Out:
#    Pressure  Year  Month  Day  Hour  Minute  Site  Latitude  Longitude  \
# 0       300  1994      1    6    23       0     3      53.6     -114.0
# 1       380  1994      1    6    23       0     3      53.6     -114.0
# 2       400  1994      1    6    23       0     3      53.6     -114.0
# 3       470  1994      1    6    23       0     3      53.6     -114.0
# 4       500  1994      1    6    23       0     3      53.6     -114.0
#
#    Ozone_ppbv
# 0   44.933333
# 1   44.175532
# 2   44.175000
# 3   39.535865
# 4   37.595341
#         Pressure  Year  Month  Day  Hour  Minute  Site  Latitude  Longitude  \
# 539798       860  2021     12   29    11      15     2      50.4     -127.4
# 539799       860  2021     12   29    11      15     3      53.6     -114.0
# 539800       870  2021     12   29    11      15     2      50.4     -127.4
# 539801       870  2021     12   29    11      15     3      53.6     -114.0
# 539802       880  2021     12   29    11      15     2      50.4     -127.4
# 539803       880  2021     12   29    11      15     3      53.6     -114.0
# 539804       890  2021     12   29    11      15     2      50.4     -127.4
# 539805       890  2021     12   29    11      15     3      53.6     -114.0
# 539806       900  2021     12   29    11      15     2      50.4     -127.4
# 539807       900  2021     12   29    11      15     3      53.6     -114.0
#
#         Ozone_ppbv
# 539798   38.278751
# 539799   36.686877
# 539800   37.957622
# 539801   35.945357
# 539802   37.030553
# 539803   34.725856
# 539804   36.433591
# 539805   33.993916
# 539806   35.733778
# 539807   33.685630
#         Pressure  Year  Month  Day  Hour  Minute  Site  Latitude  Longitude  \
# 529571       680  2021      6   22     4      50     6      34.4     -117.8
# 119312       470  2005      6    1    17      48     5      41.0     -124.2
# 510657       330  2020      7   22    11      15     2      50.4     -127.4
#
#         Ozone_ppbv
# 529571   54.256817
# 119312   29.000000
# 510657   95.136898
#    Year
# 1  1994
# 2  1994
# 3  1994
# 4  1994
# 539808
# (539808, 10)
# Index(['Pressure', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Site',
#        'Latitude', 'Longitude', 'Ozone_ppbv'],
#       dtype='object')
# Pressure        int64
# Year            int64
# Month           int64
# Day             int64
# Hour            int64
# Minute          int64
# Site            int64
# Latitude      float64
# Longitude     float64
# Ozone_ppbv    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539808 entries, 0 to 539807
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Pressure    539808 non-null  int64
#  1   Year        539808 non-null  int64
#  2   Month       539808 non-null  int64
#  3   Day         539808 non-null  int64
#  4   Hour        539808 non-null  int64
#  5   Minute      539808 non-null  int64
#  6   Site        539808 non-null  int64
#  7   Latitude    539808 non-null  float64
#  8   Longitude   539808 non-null  float64
#  9   Ozone_ppbv  539808 non-null  float64
# dtypes: float64(3), int64(7)
# memory usage: 41.2 MB
# None
